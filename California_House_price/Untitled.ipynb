# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # GradientDescent

# %%
df = pd.read_csv('./1553768847-housing.csv')

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                  41          880           129.0
# 1    -122.22     37.86                  21         7099          1106.0
# 2    -122.24     37.85                  52         1467           190.0
# 3    -122.25     37.85                  52         1274           235.0
# 4    -122.25     37.85                  52         1627           280.0
#
#    population  households  median_income ocean_proximity  median_house_value
# 0         322         126         8.3252        NEAR BAY              452600
# 1        2401        1138         8.3014        NEAR BAY              358500
# 2         496         177         7.2574        NEAR BAY              352100
# 3         558         219         5.6431        NEAR BAY              341300
# 4         565         259         3.8462        NEAR BAY              342200

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  int64
#  3   total_rooms         20640 non-null  int64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  int64
#  6   households          20640 non-null  int64
#  7   median_income       20640 non-null  float64
#  8   ocean_proximity     20640 non-null  object
#  9   median_house_value  20640 non-null  int64
# dtypes: float64(4), int64(5), object(1)
# memory usage: 1.6+ MB

# %%
df.isna().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# ocean_proximity         0
# median_house_value      0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label = LabelEncoder()

# %%
df['ocean_proximity'] = label.fit_transform(df['ocean_proximity'])

# %%
df['total_bedrooms'] = df['total_bedrooms'].fillna(df['total_bedrooms'].median())

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  int64
#  3   total_rooms         20640 non-null  int64
#  4   total_bedrooms      20640 non-null  float64
#  5   population          20640 non-null  int64
#  6   households          20640 non-null  int64
#  7   median_income       20640 non-null  float64
#  8   ocean_proximity     20640 non-null  int64
#  9   median_house_value  20640 non-null  int64
# dtypes: float64(4), int64(6)
# memory usage: 1.6 MB

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.drop('median_house_value', axis = 1)
y = df['median_house_value']

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X = scaler.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split (X, y, test_size=0.3, random_state=42)

# %%
from sklearn.linear_model import SGDRegressor

# %%
model = SGDRegressor()

# %%
model.fit(X_train,y_train)
# Out:
# SGDRegressor()

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error

# %%
np.sqrt(mean_squared_error(y_test,y_pred))
# Out:
# np.float64(69709.86018630669)

# %%
y_test.mean()
# Out:
# np.float64(206696.8142764858)

# %%
plt.plot(y_test.values, label='Actual', color='blue')
plt.plot(y_pred, label='Predicted', color='orange')
plt.legend()
plt.title('Actual vs Predicted')
plt.xlabel('Index')
plt.ylabel('Value')
plt.show()

# %% [markdown]
# # LinearRegression

# %%
df_new = pd.read_csv('./1553768847-housing.csv')

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label = LabelEncoder()

# %%
df_new['ocean_proximity'] = label.fit_transform(df_new['ocean_proximity'])

# %%
df_new['total_bedrooms'] = df_new['total_bedrooms'].fillna(df_new['total_bedrooms'].median())

# %%
from sklearn.model_selection import train_test_split

# %%
X = df_new.drop('median_house_value', axis = 1)
y = df_new['median_house_value']

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X = scaler.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split (X, y, test_size=0.3, random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
plt.plot(y_test.values, label='Actual', color='blue')
plt.plot(y_pred, label='Predicted', color='orange')
plt.legend()
plt.title('Actual vs Predicted')
plt.xlabel('Index')
plt.ylabel('Target Value')
plt.show()

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  int64
#  3   total_rooms         20640 non-null  int64
#  4   total_bedrooms      20640 non-null  float64
#  5   population          20640 non-null  int64
#  6   households          20640 non-null  int64
#  7   median_income       20640 non-null  float64
#  8   ocean_proximity     20640 non-null  int64
#  9   median_house_value  20640 non-null  int64
# dtypes: float64(4), int64(6)
# memory usage: 1.6 MB

# %%
df_new.isna().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# ocean_proximity       0
# median_house_value    0
# dtype: int64

# %%
df_new.corr()
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924664           -0.108197     0.044568
# latitude            -0.924664  1.000000            0.011173    -0.036100
# housing_median_age  -0.108197  0.011173            1.000000    -0.361262
# total_rooms          0.044568 -0.036100           -0.361262     1.000000
# total_bedrooms       0.069120 -0.066484           -0.319026     0.927058
# population           0.099773 -0.108785           -0.296244     0.857126
# households           0.055310 -0.071035           -0.302916     0.918484
# median_income       -0.015176 -0.079809           -0.119034     0.198050
# ocean_proximity     -0.289779  0.200974            0.112468    -0.015693
# median_house_value  -0.045967 -0.144160            0.105623     0.134153
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.069120    0.099773    0.055310      -0.015176
# ...

# %% [markdown]
# ## GridSearch

# %%
df_gs = pd.read_csv('./1553768847-housing.csv')

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label = LabelEncoder()

# %%
df_gs['ocean_proximity'] = label.fit_transform(df_gs['ocean_proximity'])

# %%
df_gs['total_bedrooms'] = df_gs['total_bedrooms'].fillna(df_gs['total_bedrooms'].median())

# %%
from sklearn.model_selection import train_test_split

# %%
X = df_gs.drop('median_house_value', axis = 1)
y = df_gs['median_house_value']

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X = scaler.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split (X, y, test_size=0.3, random_state=42)

# %%
from sklearn.linear_model import SGDRegressor

# %%
model = SGDRegressor()

# %%
from sklearn.model_selection import GridSearchCV

# %%
params = {
    'penalty':['11','22','elasticnet'],
    'alpha':[0.0001,0.001,0.1,1],
    'max_iter':[200,500,1000],
}

# %%
final_model = GridSearchCV(model,param_grid=params,cv=3,verbose=2,return_train_score=True)

# %%
final_model.fit(X_train,y_train)
# Out:
# Fitting 3 folds for each of 36 candidates, totalling 108 fits
# [CV] END .............alpha=0.0001, max_iter=200, penalty=11; total time=   0.0s
# [CV] END .............alpha=0.0001, max_iter=200, penalty=11; total time=   0.0s
# [CV] END .............alpha=0.0001, max_iter=200, penalty=11; total time=   0.0s
# [CV] END .............alpha=0.0001, max_iter=200, penalty=22; total time=   0.0s
# [CV] END .............alpha=0.0001, max_iter=200, penalty=22; total time=   0.0s
# [CV] END .............alpha=0.0001, max_iter=200, penalty=22; total time=   0.0s
# [CV] END .....alpha=0.0001, max_iter=200, penalty=elasticnet; total time=   0.0s
# [CV] END .....alpha=0.0001, max_iter=200, penalty=elasticnet; total time=   0.0s
# [CV] END .....alpha=0.0001, max_iter=200, penalty=elasticnet; total time=   0.0s
# [CV] END .............alpha=0.0001, max_iter=500, penalty=11; total time=   0.0s
# [CV] END .............alpha=0.0001, max_iter=500, penalty=11; total time=   0.0s
# ...

# %%
final_model.best_params_
# Out:
# {'alpha': 0.0001, 'max_iter': 200, 'penalty': 'elasticnet'}

# %%
import numpy as np

alphas = final_model.cv_results_['param_alpha'].data.astype(float)  # convert to floats if needed

plt.figure(figsize=(8, 5))
plt.plot(alphas, train_scores, marker='o', label='Train Score')
plt.plot(alphas, test_scores, marker='o', label='Test Score')
plt.xlabel('Alpha')
plt.ylabel('Score')
plt.title('Train vs Test Score by Alpha')
plt.legend()
plt.grid(True)
plt.show()
